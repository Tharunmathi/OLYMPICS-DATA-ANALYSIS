# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load dataset

# %%
athletes = pd.read_csv("C:\\Users\\THARUN\\Downloads\\DATASETS\\athlete_events.csv")
athletes
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
region = pd.read_csv("C:\\Users\\THARUN\\Downloads\\DATASETS\\noc_regions.csv")
region
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %% [markdown]
# # Join the dataframes

# %%
athletics_df = athletes.merge(region,how ="left",on = "NOC")
athletics_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
athletics_df.shape
# Out:
# (271116, 17)

# %% [markdown]
# # column name consistent

# %%
athletics_df.rename(columns = {'region':'Region','notes':'Notes'},inplace = True)

# %%
athletics_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       Region Notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
athletics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270746 non-null  object
#  16  Notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
athletics_df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# # check null values

# %%
athletics_df.isnull().any()
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# Region     True
# Notes      True
# dtype: bool

# %%
athletics_df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       370
# Notes     266077
# dtype: int64

# %% [markdown]
# # Los Angeles details

# %%
athletics_df[athletics_df["City"] == "Los Angeles"]
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 88          27                       Johan Aantjes   M  26.0     NaN     NaN
# 189         85             Alejandro Abascal Garca   M  32.0   181.0    82.0
# 191         86             Jos Manuel Abascal Gmez   M  26.0   182.0    67.0
# ...        ...                                 ...  ..   ...     ...     ...
# 270774  135416                           Star Zulu   M   NaN     NaN     NaN
# 270814  135441                Rafael Zuiga Medrano   M  21.0   173.0    57.0
# 270822  135445                             Zuo Yue   M  21.0   192.0    88.0
# 270913  135480                        Geeta Zutshi   F  27.0   167.0    51.0
# 271021  135527                         Rolf Zwicky   M  26.0   175.0    70.0
#
# ...

# %% [markdown]
# # India details

# %%
athletics_df[athletics_df["Team"] == "India"]
# Out:
#             ID                                           Name Sex   Age  \
# 505        281                                 S. Abdul Hamid   M   NaN
# 506        281                                 S. Abdul Hamid   M   NaN
# 895        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 896        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 897        512                Shiny Kurisingal Abraham-Wilson   F  23.0
# ...        ...                                            ...  ..   ...
# 264139  132177                           Mohammad Anas Yahiya   M  21.0
# 265876  133029  Thyadathuvilla Chandrapillai "T. C." Yohannan   M  29.0
# 266934  133554                           Sayed Muhammad Yusuf   M   NaN
# 270912  135480                                   Geeta Zutshi   F  23.0
# 270913  135480                                   Geeta Zutshi   F  27.0
#
#         Height  Weight   Team  NOC        Games  Year  Season            City  \
# ...

# %% [markdown]
# # Japan details

# %%
athletics_df[athletics_df["Team"] == "Japan"]
# Out:
#             ID            Name Sex   Age  Height  Weight   Team  NOC  \
# 625        362     Isao Ko Abe   M  24.0   177.0    75.0  Japan  JPN
# 629        363      Kazumi Abe   M  28.0   178.0    67.0  Japan  JPN
# 630        364       Kazuo Abe   M  25.0   166.0    69.0  Japan  JPN
# 631        365       Kinya Abe   M  23.0   168.0    68.0  Japan  JPN
# 632        366     Kiyoshi Abe   M  25.0   167.0    62.0  Japan  JPN
# ...        ...             ...  ..   ...     ...     ...    ...  ...
# 266953  133565  Tsuneya Yuzaki   M  19.0   174.0    67.0  Japan  JPN
# 266954  133565  Tsuneya Yuzaki   M  23.0   174.0    67.0  Japan  JPN
# 266955  133565  Tsuneya Yuzaki   M  27.0   174.0    67.0  Japan  JPN
# 266957  133566      Ryo Yuzawa   M  27.0   175.0    76.0  Japan  JPN
# 268117  134133   Kotoki Zayasu   F  26.0   159.0    57.0  Japan  JPN
#
#               Games  Year  Season            City         Sport  \
# 625     1936 Summer  1936  Summer          Berlin     Athletics
# ...

# %% [markdown]
# # Top countries participating

# %%
top_10_countries = athletics_df["Team"].value_counts()
top_10_countries.head(10)
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %% [markdown]
# # plot for top 10 countries

# %%
plt.figure(figsize = (58,14))
plt.title("Over all Participation by country")
sns.barplot(x=top_10_countries.index, y=top_10_countries, palette = "Set2");
plt.show()

# %% [markdown]
# # Age distribution of the participants

# %%
plt.figure(figsize=(12,6))
plt.title("Age Distribution of the athletes")
plt.xlabel("Age")
plt.ylabel("Number of Participants")
plt.hist(athletics_df.Age,bins = np.arange(10,80,2),color = "orange",edgecolor = "white")
plt.show()

# %%
winter_sports = athletics_df[athletics_df.Season =="Winter"].Sport.unique()
winter_sports
# Out:
# array(['Speed Skating', 'Cross Country Skiing', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Luge', 'Bobsleigh', 'Figure Skating',
#        'Nordic Combined', 'Freestyle Skiing', 'Ski Jumping', 'Curling',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton',
#        'Military Ski Patrol', 'Alpinism'], dtype=object)

# %% [markdown]
# # summer sports

# %%
summer_sports = athletics_df[athletics_df.Season =="Summer"].Sport.unique()
summer_sports
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %% [markdown]
# # Male and female participants

# %%
athletics_df[athletics_df["Sex"] =="M"]
# Out:
#             ID                  Name Sex   Age  Height  Weight  \
# 0            1             A Dijiang   M  24.0   180.0    80.0
# 1            2              A Lamusi   M  23.0   170.0    60.0
# 2            3   Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4  Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 10           6       Per Knut Aaland   M  31.0   188.0    75.0
# ...        ...                   ...  ..   ...     ...     ...
# 271111  135569            Andrzej ya   M  29.0   179.0    89.0
# 271112  135570              Piotr ya   M  27.0   176.0    59.0
# 271113  135570              Piotr ya   M  27.0   176.0    59.0
# 271114  135571    Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571    Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
athletics_df[athletics_df["Sex"] =="F"]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 4            5             Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5             Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5             Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5             Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5             Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271099  135560                    Stavroula Zygouri   F  36.0   171.0    63.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
# 271110  135568               Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
gender_counts = athletics_df["Sex"].value_counts()
gender_counts
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %% [markdown]
# # pie plot for male and female athletes

# %%
plt.figure(figsize=(12,6))
plt.title("Gender Distribution")
plt.pie(gender_counts,labels = gender_counts.index,autopct = '%1.1f%%',startangle = 150,shadow = True)
plt.show()

# %% [markdown]
# # Total medals

# %%
athletics_df["Medal"].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %% [markdown]
# # Total number of female athletics in each olympics.

# %%
female_participants = athletics_df[(athletics_df["Sex"] == "F") & (athletics_df["Season"] =="Summer")][["Sex","Year"]]
female_participants = female_participants.groupby("Year").count().reset_index()
female_participants.tail()
# Out:
#     Year   Sex
# 23  2000  5431
# 24  2004  5546
# 25  2008  5816
# 26  2012  5815
# 27  2016  6223

# %%
women_olympics = athletics_df[(athletics_df["Sex"] == "F") & (athletics_df["Season"] =="Summer")]
women_olympics
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 26           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 32          13                   Minna Maarit Aalto   F  30.0   159.0    55.5
# 33          13                   Minna Maarit Aalto   F  34.0   159.0    55.5
# 79          21            Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271099  135560                    Stavroula Zygouri   F  36.0   171.0    63.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
# 271110  135568               Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
sns.set(style = 'darkgrid')
plt.figure(figsize = (20,10))
sns.countplot(x= "Year",data = women_olympics,palette = "Spectral")
plt.title("Women Participation")
plt.show()

# %%
part = women_olympics.groupby("Year")["Sex"].value_counts()
plt.figure(figsize = (20,10))
part.loc[:,"F"].plot()
plt.title("Plot of Female Athletes over time")
plt.show()

# %% [markdown]
# # Gold medal athletes

# %%
gold_medals = athletics_df[athletics_df["Medal"] == "Gold"]
gold_medals.head(5)
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal   Region Notes
# 3        Tug-Of-War Men's Tug-Of-War  Gold  Denmark   NaN
# ...

# %% [markdown]
# # Take only the values that are different from Nan

# %%
gold_medals = gold_medals[np.isfinite(gold_medals["Age"])]
gold_medals
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
# ...

# %% [markdown]
# # Gold beyond 60

# %%
gold_medals[gold_medals["Age"] > 60]
# Out:
#             ID                                     Name Sex   Age  Height  \
# 104003   52626                     Isaac Lazarus Israls   M  63.0     NaN
# 105199   53238                          Charles Jacobus   M  64.0     NaN
# 190952   95906  Lida Peyton "Eliza" Pollock (McMillen-)   F  63.0     NaN
# 226374  113773             Galen Carter "G. C." Spencer   M  63.0   165.0
# 233390  117046                        Oscar Gomer Swahn   M  64.0     NaN
# 261102  130662                  Robert W. Williams, Jr.   M  63.0     NaN
#
#         Weight                Team  NOC        Games  Year  Season       City  \
# 104003     NaN         Netherlands  NED  1928 Summer  1928  Summer  Amsterdam
# 105199     NaN       United States  USA  1904 Summer  1904  Summer  St. Louis
# 190952     NaN  Cincinnati Archers  USA  1904 Summer  1904  Summer  St. Louis
# 226374     NaN     Potomac Archers  USA  1904 Summer  1904  Summer  St. Louis
# ...

# %%
sporting_event = gold_medals["Sport"][gold_medals["Age"]> 60]
sporting_event
# Out:
# 104003    Art Competitions
# 105199               Roque
# 190952             Archery
# 226374             Archery
# 233390            Shooting
# 261102             Archery
# Name: Sport, dtype: object

# %% [markdown]
# # plot for sporting _event

# %%
plt.figure(figsize = (10,5))
plt.tight_layout()
sns.countplot(sporting_event)
plt.title('Gold medals for athletes over 60 years')
plt.show()
# Out:
# c:\users\tharun\downloads\fda\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Gold medals from each country

# %%
gold_medals["Region"].value_counts().reset_index(name = "Medal").head(5)
# Out:
#      index  Medal
# 0      USA   2627
# 1   Russia   1599
# 2  Germany   1293
# 3       UK    657
# 4    Italy    567

# %%
totalGoldmedals=gold_medals["Region"].value_counts().reset_index(name = "Medal").head(5)
g = sns.catplot(x="index",y = "Medal",data = totalGoldmedals,height= 5,kind = "bar",palette = "rocket")
g.despine(left = True)
g.set_xlabels("Top 5 countries")
g.set_ylabels("Number of medals")
plt.title("Gold medals per country")
plt.show()

# %% [markdown]
# # Rio olympics

# %%
max_year = athletics_df.Year.max()
print(max_year)
team_names = athletics_df[(athletics_df["Year"] == max_year)&(athletics_df["Medal"] == "Gold")]['Team']
team_names.value_counts().head(10)
# Out:
# 2016
# United States    137
# Great Britain     64
# Russia            50
# Germany           47
# China             44
# Brazil            34
# Australia         23
# Argentina         21
# France            20
# Japan             17
# Name: Team, dtype: int64

# %%
sns.barplot(x = team_names.value_counts().head(20),y = team_names.value_counts().head(20).index)
plt.ylabel(None)
plt.xlabel("Country wise medals for the year 2016")
# Out:
# Text(0.5, 0, 'Country wise medals for the year 2016')

# %%
not_null_medals = athletics_df[(athletics_df["Height"].notnull())&(athletics_df["Weight"].notnull())]

# %%
plt.figure(figsize=(12,10))
axis = sns.scatterplot(x = "Height",y = 'Weight',data = not_null_medals,hue = 'Sex')
plt.title("Height vs Weight of Olympics Medalists")
plt.show()
